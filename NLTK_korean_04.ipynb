# %% [markdown]
# <a href="https://colab.research.google.com/github/SanghunOh/exec_bigdataservice/blob/main/NLTK_korean_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !ls ./drive/MyDrive/Test/smtph_total.csv
# Out:
# ./drive/MyDrive/Test/smtph_total.csv

# %%
df = pd.read_csv('./drive/MyDrive/Test/smtph_total.csv')
df.head(5)
# Out:
#                              Title  ...                                      Post Contents
# 0   갤럭시 Z 플립과 한 달, 접는 스마트폰의 가치만 남다  ...                                                NaN
# 1              스마트폰 삼각대 추천 내돈내산 리뷰  ...  \n\n\n\n\n\n\n솜이언니 일상\n\n\n\n\n스마트폰 삼각대 추천 내돈내...
# 2       차 키를 스마트폰으로! 카버샵 더컵 실사용 후기  ...  \n\n\n\n\n\n\n상품 리뷰\n\n\n\n\n차 키를 스마트폰으로! 카버샵 ...
# 3            대전스마트폰복구 삭제나 고장도 걱정없이  ...  \n\n안녕하세요 모아입니다.바쁜 현대인들의 곁에서어디서든 일상을 함께하는 스마트폰...
# 4  삼성 갤럭시노트10 가격 2021년에도 매력적인 스마트폰  ...  \n\n\n\n\n\n\n모바일/태블릿\n\n\n\n\n삼성 갤럭시노트10 가격 2...
#
# [5 rows x 7 columns]

# %%
posts = df['Description']
posts[0]
# Out:
# '반으로 접을 수 있는 갤럭시 Z 플립이 접지 않는 스마트폰과 얼마나 다른 경험인가를… 여기에는 조금 복잡한 관점이 들어 있다. 기존 스마트폰의 기능성을 유지하면서 접은 것인지, 그냥 접는 의미만 살린... '

# %%
# !python -m pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 448 kB 41.2 MB/s
# ...
#      |████████████████████████████████| 86 kB 4.8 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
# !python -m pip install eunjeon
# Out:
# ...
#      |████████████████████████████████| 34.7 MB 61 kB/s
# WARNING: Discarding https://files.pythonhosted.org/packages/68/90/3232725f974abf6d38f1e2cfd7a6b958337133b3fdc5b3e8994e03d7c2d3/eunjeon-0.4.0.tar.gz#sha256=60865fbe28537e820ab864cd135467ea277c8182908e2bc364e83e5fd29ef07f (from https://pypi.org/simple/eunjeon/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ...
#      |████████████████████████████████| 34.7 MB 53 kB/s
# WARNING: Discarding https://files.pythonhosted.org/packages/64/d3/743807b1ec82a99872ad785c5c244a6806ecbc3ba369cf09fdc1c4767509/eunjeon-0.3.9.6.tar.gz#sha256=d088714a537d999e16afb1cd3c1375c81fd1f03a169c47c95250ee5b704e1bd5 (from https://pypi.org/simple/eunjeon/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ...
#      |████████████████████████████████| 34.1 MB 74 kB/s
# ...

# %%
from konlpy.tag import Mecab
tagger = Mecab()
